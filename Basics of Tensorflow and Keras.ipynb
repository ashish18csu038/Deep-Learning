# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing the libraries
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, -1]

X = X.values
y = y.values

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])

labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])


from sklearn.compose import ColumnTransformer 
ct = ColumnTransformer([("Country", OneHotEncoder(),[1])], remainder="passthrough") # The last arg ([0]) is the list of columns you want to transform in this step
X = ct.fit_transform(X) 
X = X[:, 1:]

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import tensorflow as tf
print ("TensorFlow version: " + tf.__version__)



from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer (2 layers are added by this one function call)
# units = 6 comes from average of input layer + output layer (11 + 1)/2
classifier.add(Dense(input_dim = 11, units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
# For a logistic regression, we dont use the sum of squared residual loss function
# We use binary cross entropy if we have 1 binary outcome and
# categorical cross entropy if we have more than one categorical outcome
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# TensorFlow version: 2.3.1
# Epoch 1/100
# 800/800 [==============================] - 1s 803us/step - loss: 0.4774 - accuracy: 0.7989
# Epoch 2/100
# 800/800 [==============================] - 1s 825us/step - loss: 0.4222 - accuracy: 0.7989
# Epoch 3/100
# 800/800 [==============================] - 1s 821us/step - loss: 0.4157 - accuracy: 0.8091
# Epoch 4/100
# 800/800 [==============================] - 1s 844us/step - loss: 0.4120 - accuracy: 0.8250
# Epoch 5/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4101 - accuracy: 0.8304
# Epoch 6/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4081 - accuracy: 0.8317
# Epoch 7/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4061 - accuracy: 0.8340
# Epoch 8/100
# 800/800 [==============================] - 1s 940us/step - loss: 0.4044 - accuracy: 0.8342
# Epoch 9/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.4029 - accuracy: 0.8353
# Epoch 10/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4012 - accuracy: 0.8371
# Epoch 11/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.4010 - accuracy: 0.8375
# Epoch 12/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3998 - accuracy: 0.8381
# Epoch 13/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3996 - accuracy: 0.8380
# Epoch 14/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3986 - accuracy: 0.8386
# Epoch 15/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3981 - accuracy: 0.8386
# Epoch 16/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3975 - accuracy: 0.8390
# Epoch 17/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3971 - accuracy: 0.8389
# Epoch 18/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3971 - accuracy: 0.8396
# Epoch 19/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3964 - accuracy: 0.8400
# Epoch 20/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3961 - accuracy: 0.8389
# Epoch 21/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3957 - accuracy: 0.8403
# Epoch 22/100
# 800/800 [==============================] - 1s 995us/step - loss: 0.3959 - accuracy: 0.8399
# Epoch 23/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3954 - accuracy: 0.8401
# Epoch 24/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3958 - accuracy: 0.8378
# Epoch 25/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3951 - accuracy: 0.8389
# Epoch 26/100
# 800/800 [==============================] - 1s 686us/step - loss: 0.3945 - accuracy: 0.8394
# Epoch 27/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3951 - accuracy: 0.8399
# Epoch 28/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3949 - accuracy: 0.8399
# Epoch 29/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3947 - accuracy: 0.8399
# Epoch 30/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3945 - accuracy: 0.8403
# Epoch 31/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3942 - accuracy: 0.8415
# Epoch 32/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3941 - accuracy: 0.8405
# Epoch 33/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3940 - accuracy: 0.8394
# Epoch 34/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3942 - accuracy: 0.8404
# Epoch 35/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3936 - accuracy: 0.8413
# Epoch 36/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3937 - accuracy: 0.8403
# Epoch 37/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3936 - accuracy: 0.8410
# Epoch 38/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3934 - accuracy: 0.8399
# Epoch 39/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3933 - accuracy: 0.8396
# Epoch 40/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3934 - accuracy: 0.8389
# Epoch 41/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3934 - accuracy: 0.8395
# Epoch 42/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3933 - accuracy: 0.8403
# Epoch 43/100
# 800/800 [==============================] - 1s 944us/step - loss: 0.3923 - accuracy: 0.8415
# Epoch 44/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3931 - accuracy: 0.8407
# Epoch 45/100
# 800/800 [==============================] - 1s 987us/step - loss: 0.3930 - accuracy: 0.8406
# Epoch 46/100
# 800/800 [==============================] - 1s 982us/step - loss: 0.3928 - accuracy: 0.8397
# Epoch 47/100
# 800/800 [==============================] - 1s 966us/step - loss: 0.3929 - accuracy: 0.8397
# Epoch 48/100
# 800/800 [==============================] - 1s 956us/step - loss: 0.3922 - accuracy: 0.8401
# Epoch 49/100
# 800/800 [==============================] - 1s 945us/step - loss: 0.3929 - accuracy: 0.8403
# Epoch 50/100
# 800/800 [==============================] - 1s 941us/step - loss: 0.3927 - accuracy: 0.8415
# Epoch 51/100
# 800/800 [==============================] - 1s 946us/step - loss: 0.3925 - accuracy: 0.8415
# Epoch 52/100
# 800/800 [==============================] - 1s 950us/step - loss: 0.3929 - accuracy: 0.8401
# Epoch 53/100
# 800/800 [==============================] - 1s 914us/step - loss: 0.3925 - accuracy: 0.8404
# Epoch 54/100
# 800/800 [==============================] - 1s 795us/step - loss: 0.3927 - accuracy: 0.8414
# Epoch 55/100
# 800/800 [==============================] - 1s 803us/step - loss: 0.3927 - accuracy: 0.8421
# Epoch 56/100
# 800/800 [==============================] - 1s 819us/step - loss: 0.3926 - accuracy: 0.8415
# Epoch 57/100
# 800/800 [==============================] - 1s 777us/step - loss: 0.3923 - accuracy: 0.8405
# Epoch 58/100
# 800/800 [==============================] - 1s 821us/step - loss: 0.3922 - accuracy: 0.8413
# Epoch 59/100
# 800/800 [==============================] - 1s 832us/step - loss: 0.3926 - accuracy: 0.8419
# Epoch 60/100
# 800/800 [==============================] - 1s 943us/step - loss: 0.3922 - accuracy: 0.8416
# Epoch 61/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3925 - accuracy: 0.8413
# Epoch 62/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3923 - accuracy: 0.8419
# Epoch 63/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8414
# Epoch 64/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8399
# Epoch 65/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8411
# Epoch 66/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8416
# Epoch 67/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3921 - accuracy: 0.8396
# Epoch 68/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3925 - accuracy: 0.8403
# Epoch 69/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3919 - accuracy: 0.8403
# Epoch 70/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3919 - accuracy: 0.8399
# Epoch 71/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3924 - accuracy: 0.8404
# Epoch 72/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8428
# Epoch 73/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3923 - accuracy: 0.8404
# Epoch 74/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3921 - accuracy: 0.8411
# Epoch 75/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3922 - accuracy: 0.8409
# Epoch 76/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3923 - accuracy: 0.8407
# Epoch 77/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3921 - accuracy: 0.8411
# Epoch 78/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3921 - accuracy: 0.8429
# Epoch 79/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3921 - accuracy: 0.8411
# Epoch 80/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3923 - accuracy: 0.8413
# Epoch 81/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3922 - accuracy: 0.8407
# Epoch 82/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3919 - accuracy: 0.8415
# Epoch 83/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3920 - accuracy: 0.8418
# Epoch 84/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3920 - accuracy: 0.8406
# Epoch 85/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3917 - accuracy: 0.8405
# Epoch 86/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3921 - accuracy: 0.8419
# Epoch 87/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3923 - accuracy: 0.8425
# Epoch 88/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3917 - accuracy: 0.8404
# Epoch 89/100
# 800/800 [==============================] - 2s 2ms/step - loss: 0.3923 - accuracy: 0.8394
# Epoch 90/100
# 800/800 [==============================] - 1s 2ms/step - loss: 0.3917 - accuracy: 0.8420
# Epoch 91/100
# 800/800 [==============================] - 1s 811us/step - loss: 0.3917 - accuracy: 0.8404
# Epoch 92/100
# 800/800 [==============================] - 1s 911us/step - loss: 0.3912 - accuracy: 0.8426
# Epoch 93/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3920 - accuracy: 0.8405
# Epoch 94/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3912 - accuracy: 0.8411
# Epoch 95/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3921 - accuracy: 0.8397
# Epoch 96/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3916 - accuracy: 0.8429
# Epoch 97/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3920 - accuracy: 0.8394
# Epoch 98/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3918 - accuracy: 0.8406
# Epoch 99/100
# 800/800 [==============================] - 1s 1ms/step - loss: 0.3919 - accuracy: 0.8415
# Epoch 100/100
# 800/800 [==============================] - 1s 907us/step - loss: 0.3915 - accuracy: 0.8401

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1492,   80],
#        [ 287,  141]], dtype=int64)
